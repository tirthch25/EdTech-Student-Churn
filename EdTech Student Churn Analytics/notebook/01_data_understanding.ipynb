# %%
#1. Import Required Libraries
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\tirth\\EdTech-Student-Churn\\notebooks'

# %%
#2. Load All Raw CSV Files
RAW_DATA_PATH = "../data/raw"

student_info = pd.read_csv(f"{RAW_DATA_PATH}/studentInfo.csv")
student_vle = pd.read_csv(f"{RAW_DATA_PATH}/studentVle.csv")
vle = pd.read_csv(f"{RAW_DATA_PATH}/vle.csv")
assessments = pd.read_csv(f"{RAW_DATA_PATH}/assessments.csv")
student_assessment = pd.read_csv(f"{RAW_DATA_PATH}/studentAssessment.csv")

# %%
#3. Dataset Overview (Shape & Samples)
student_info.shape
student_info.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# ...

# %%
student_vle.shape
student_vle.head()
# Out:
#   code_module code_presentation  id_student  id_site  date  sum_click
# 0         AAA             2013J       28400   546652   -10          4
# 1         AAA             2013J       28400   546652   -10          1
# 2         AAA             2013J       28400   546652   -10          1
# 3         AAA             2013J       28400   546614   -10         11
# 4         AAA             2013J       28400   546714   -10          1

# %%
student_assessment.shape
student_assessment.head()
# Out:
#    id_assessment  id_student  date_submitted  is_banked  score
# 0           1752       11391              18          0   78.0
# 1           1752       28400              22          0   70.0
# 2           1752       31604              17          0   72.0
# 3           1752       32885              26          0   69.0
# 4           1752       38053              19          0   79.0

# %%
assessments.shape
assessments.head()
# Out:
#   code_module code_presentation  id_assessment assessment_type   date  weight
# 0         AAA             2013J           1752             TMA   19.0    10.0
# 1         AAA             2013J           1753             TMA   54.0    20.0
# 2         AAA             2013J           1754             TMA  117.0    20.0
# 3         AAA             2013J           1755             TMA  166.0    20.0
# 4         AAA             2013J           1756             TMA  215.0    30.0

# %%
vle.shape
vle.head()
# Out:
#    id_site code_module code_presentation activity_type  week_from  week_to
# 0   546943         AAA             2013J      resource        NaN      NaN
# 1   546712         AAA             2013J     oucontent        NaN      NaN
# 2   546998         AAA             2013J      resource        NaN      NaN
# 3   546888         AAA             2013J           url        NaN      NaN
# 4   547035         AAA             2013J      resource        NaN      NaN

# %%
#4. Schema & Data Types Check
student_info.info()
student_vle.info()
student_assessment.info()
assessments.info()
vle.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32593 entries, 0 to 32592
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   code_module           32593 non-null  object
#  1   code_presentation     32593 non-null  object
#  2   id_student            32593 non-null  int64
#  3   gender                32593 non-null  object
#  4   region                32593 non-null  object
#  5   highest_education     32593 non-null  object
#  6   imd_band              31482 non-null  object
#  7   age_band              32593 non-null  object
#  8   num_of_prev_attempts  32593 non-null  int64
#  9   studied_credits       32593 non-null  int64
#  10  disability            32593 non-null  object
#  11  final_result          32593 non-null  object
# dtypes: int64(3), object(9)
# memory usage: 3.0+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10655280 entries, 0 to 10655279
# ...

# %%
#5. Missing Value Inspection
def missing_summary(df):
    return df.isnull().sum().sort_values(ascending=False)

missing_summary(student_info)
missing_summary(student_vle)
missing_summary(student_assessment)
# Out:
# score             173
# id_assessment       0
# id_student          0
# date_submitted      0
# is_banked           0
# dtype: int64

# %%
#6. Initial Churn Signal Exploration
#6.1 Final Result Distribution
student_info['final_result'].value_counts()
# Out:
# final_result
# Pass           12361
# Withdrawn      10156
# Fail            7052
# Distinction     3024
# Name: count, dtype: int64

# %%
#6.2 Engagement Summary
student_vle['sum_click'].describe()
# Out:
# count    1.065528e+07
# mean     3.716946e+00
# std      8.849047e+00
# min      1.000000e+00
# 25%      1.000000e+00
# 50%      2.000000e+00
# 75%      3.000000e+00
# max      6.977000e+03
# Name: sum_click, dtype: float64

# %%
#6.3 Assessment Score Overview
student_assessment['score'].describe()
# Out:
# count    173739.000000
# mean         75.799573
# std          18.798107
# min           0.000000
# 25%          65.000000
# 50%          80.000000
# 75%          90.000000
# max         100.000000
# Name: score, dtype: float64

# %% [markdown]
# 7. Key Observations (WRITE THESE AS MARKDOWN)
#
# Dataset contains behavioral, academic, and demographic information
#
# studentVle.csv provides fine-grained engagement signals
#
# Withdrawn in final_result will be used as churn label
#
# Missing assessment scores may indicate disengagement
#
# Engagement intensity varies significantly across students
#
# 8. Conclusion of Data Understanding
#
# A Markdown cell:
#
# Conclusion:
#
# Multiple datasets capture different aspects of student behavior
#
# Behavioral engagement and assessment activity are likely strong predictors of dropout
#
# Next step is to clean, engineer features, and merge datasets into a student-level table
#
# What we Have Achieved:
#
# ✔ Understood all raw datasets
# ✔ Identified churn label
# ✔ Identified key behavioral signals
# ✔ Set foundation for merging & feature engineering
